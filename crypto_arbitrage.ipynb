# %% [markdown]
# ## Crypto Arbitrage
#
# In this Challenge, you'll take on the role of an analyst at a high-tech investment firm. The vice president (VP) of your department is considering arbitrage opportunities in Bitcoin and other cryptocurrencies. As Bitcoin trades on markets across the globe, can you capitalize on simultaneous price dislocations in those markets by using the powers of Pandas?
#
# For this assignment, you’ll sort through historical trade data for Bitcoin on two exchanges: Bitstamp and Coinbase. Your task is to apply the three phases of financial analysis to determine if any arbitrage opportunities exist for Bitcoin.
#
# This aspect of the Challenge will consist of 3 phases.
#
# 1. Collect the data.
#
# 2. Prepare the data.
#
# 3. Analyze the data.

# %% [markdown]
# ###  Import the required libraries and dependencies.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# ## Collect the Data
#
# To collect the data that you’ll need, complete the following steps:
#
# Instructions.
#
# 1. Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.
#
# 2. Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.
#
# 3. Repeat Steps 1 and 2 for `coinbase.csv` file.

# %% [markdown]
# ### Step 1: Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.

# %%
# Read in the CSV file called "bitstamp.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Date"
# Set the parse_dates and infer_datetime_format parameters

bitstamp_path = Path("./Resources/bitstamp.csv")
bitstamp = pd.read_csv(
    bitstamp_path,
    index_col="Timestamp",
    infer_datetime_format=True,
    parse_dates=True
)

# %% [markdown]
# ### Step 2: Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
bitstamp.head()
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %% [markdown]
# ### Step 3: Repeat Steps 1 and 2 for `coinbase.csv` file.

# %%
# Read in the CSV file called "coinbase.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Timestamp"
# Set the parse_dates and infer_datetime_format parameters
coinbase_path = Path("./Resources/coinbase.csv")
coinbase = pd.read_csv(
    coinbase_path,
    index_col="Timestamp",
    infer_datetime_format=True,
    parse_dates=True,
)

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
coinbase.head(7)
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
# 2018-01-01 00:05:00  13583.45  13583.45  13564.29  $13564.35    4.746346
# 2018-01-01 00:06:00  13583.28  13583.28  13510.59   $13539.0   25.791324
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401
# 2018-01-01 00:05:00   64468.68052    13582.802658
# ...

# %% [markdown]
# ## Prepare the Data
#
# To prepare and clean your data for analysis, complete the following steps:
#
# 1. For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.
#
# 2. Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.
#
# 3. Convert the data type of the Close column to a `float`.
#
# 4. Review the data for duplicated values, and drop them if necessary.
#
# 5. Repeat Steps 1–4 for the coinbase DataFrame.

# %% [markdown]
# ### Step 1: For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.

# %%
# For the bitstamp DataFrame, replace or drop all NaNs or missing values in the DataFrame
import pandas as pd
bitstamp = bitstamp.dropna()
bitstamp
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
# ...                       ...       ...       ...        ...         ...
# 2018-03-31 23:55:00   6935.01   6939.07   6922.56   $6922.56    1.044354
# 2018-03-31 23:56:00   6922.02   6922.02   6918.00   $6920.32    3.069539
# 2018-03-31 23:57:00   6920.33   6936.42   6920.33   $6934.72   28.239049
# 2018-03-31 23:58:00   6927.65   6929.42   6927.65   $6927.65    0.839507
# 2018-03-31 23:59:00   6929.98   6929.98   6928.00   $6928.01    0.209363
#
#                         USD Volume  Weighted Price
# Timestamp
# ...

# %%
bitstamp.info()
#This provides us with information about the dataframe, # of columns, column headers, and the data type.
#Note that the "Close" column has objects as data types, these need to be float values so they can be calculated
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 129067 entries, 2018-01-01 00:00:00 to 2018-03-31 23:59:00
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Open            129067 non-null  float64
#  1   High            129067 non-null  float64
#  2   Low             129067 non-null  float64
#  3   Close           129067 non-null  object
#  4   BTC Volume      129067 non-null  float64
#  5   USD Volume      129067 non-null  float64
#  6   Weighted Price  129067 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 7.9+ MB

# %%
#Making sure there are no empty rows
bitstamp.isnull().sum()
# Out:
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %%
#I want to check what type of data I have
bitstamp.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close              object
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
#use the str.replace function to remove the dollar sign, $
bitstamp.loc[:, "Close"] = bitstamp.loc[:, "Close"].str.replace("$","")
bitstamp

#this error message tells us that the datatypes under the "Close" column aren't all strings. 
#the formula did remove the "$" from each value.
# Out:
# C:\Users\reson\AppData\Local\Temp\ipykernel_35060\828422447.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   bitstamp.loc[:, "Close"] = bitstamp.loc[:, "Close"].str.replace("$","")
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   13620.0    1.069665
# ...                       ...       ...       ...       ...         ...
# 2018-03-31 23:55:00   6935.01   6939.07   6922.56   6922.56    1.044354
# ...

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close data type to a float
bitstamp.loc[:, "Close"] = bitstamp.loc[:, "Close"].astype("float")
bitstamp
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00  13620.00    1.069665
# ...                       ...       ...       ...       ...         ...
# 2018-03-31 23:55:00   6935.01   6939.07   6922.56   6922.56    1.044354
# 2018-03-31 23:56:00   6922.02   6922.02   6918.00   6920.32    3.069539
# 2018-03-31 23:57:00   6920.33   6936.42   6920.33   6934.72   28.239049
# 2018-03-31 23:58:00   6927.65   6929.42   6927.65   6927.65    0.839507
# 2018-03-31 23:59:00   6929.98   6929.98   6928.00   6928.01    0.209363
#
#                         USD Volume  Weighted Price
# Timestamp
# ...

# %%
#checking data type, should be all 'float'
bitstamp.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Review the data for duplicate values, and drop them if necessary
# This formula looks for duplicates. There are none. Making sure there are NO duplicates
bitstamp.duplicated().sum()
# Out:
# 0

# %%
#Making sure there are no other empty rows
bitstamp.isnull().sum()
# Out:
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %% [markdown]
# ### Step 5: Repeat Steps 1–4 for the coinbase DataFrame.

# %%
# Repeat Steps 1–4 for the coinbase DataFrame
coinbase = coinbase.dropna()
coinbase
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
# ...                       ...       ...       ...        ...         ...
# 2018-03-31 23:55:00   6945.20   6948.06   6930.00    $6930.0    5.802288
# 2018-03-31 23:56:00   6930.00   6930.01   6930.00   $6930.01    0.625053
# 2018-03-31 23:57:00   6930.01   6933.91   6930.01   $6933.91    0.776431
# 2018-03-31 23:58:00   6933.91   6938.00   6933.90   $6937.31    0.133413
# 2018-03-31 23:59:00   6937.30   6937.30   6931.09    $6934.0    1.012720
#
#                         USD Volume  Weighted Price
# Timestamp
# ...

# %%
#making sure there are no empty rows
coinbase.isnull().sum()
# Out:
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %%
#Remove the $ from the values in the "Close" column

coinbase.loc[:, "Close"] = coinbase.loc[:, "Close"].str.replace("$","")
coinbase
# Out:
# C:\Users\reson\AppData\Local\Temp\ipykernel_35060\3011834378.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   coinbase.loc[:, "Close"] = coinbase.loc[:, "Close"].str.replace("$","")
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  13583.44    9.955364
# ...                       ...       ...       ...       ...         ...
# 2018-03-31 23:55:00   6945.20   6948.06   6930.00    6930.0    5.802288
# ...

# %%
#Convert data type as 'float'
coinbase.loc[:, "Close"] = coinbase.loc[:, "Close"].astype(float)
coinbase

#last dates of the dataframe are 3/31/2018
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00  13580.00   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  13583.44    9.955364
# ...                       ...       ...       ...       ...         ...
# 2018-03-31 23:55:00   6945.20   6948.06   6930.00   6930.00    5.802288
# 2018-03-31 23:56:00   6930.00   6930.01   6930.00   6930.01    0.625053
# 2018-03-31 23:57:00   6930.01   6933.91   6930.01   6933.91    0.776431
# 2018-03-31 23:58:00   6933.91   6938.00   6933.90   6937.31    0.133413
# 2018-03-31 23:59:00   6937.30   6937.30   6931.09   6934.00    1.012720
#
#                         USD Volume  Weighted Price
# Timestamp
# ...

# %%
#check that it worked
coinbase.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %%
#Make sure there are no duplicate rows
coinbase.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Analyze the Data
#
# Your analysis consists of the following tasks:
#
# 1. Choose the columns of data on which to focus your analysis.
#
# 2. Get the summary statistics and plot the data.
#
# 3. Focus your analysis on specific dates.
#
# 4. Calculate the arbitrage profits.

# %% [markdown]
# ### Step 1: Choose columns of data on which to focus your analysis.
#
# Select the data you want to analyze. Use `loc` or `iloc` to select the following columns of data for both the bitstamp and coinbase DataFrames:
#
# * Timestamp (index)
#
# * Close

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from bitstamp DataFrame

bitstamp_sliced = bitstamp.loc[:,['Close']]
print()
print("Bitcoin prices on Bitstamp at Close indexed by Timestamp")
# Review the first five rows of the DataFrame
bitstamp_sliced.head()
# Out:
# Bitcoin prices on Bitstamp at Close indexed by Timestamp
#                         Close
# Timestamp
# 2018-01-01 00:00:00  13646.48
# 2018-01-01 00:01:00  13658.75
# 2018-01-01 00:02:00  13610.22
# 2018-01-01 00:03:00  13639.09
# 2018-01-01 00:04:00  13620.00

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from coinbase DataFrame
coinbase_sliced = coinbase.iloc[:,[3]]
print()
print("Bitcoin prices on Coinbase at Close indexed by Timestamp")
# Review the first five rows of the DataFrame
coinbase_sliced.head()
# Out:
# Bitcoin prices on Coinbase at Close indexed by Timestamp
#                         Close
# Timestamp
# 2018-01-01 00:00:00  13608.49
# 2018-01-01 00:01:00  13601.66
# 2018-01-01 00:02:00  13580.00
# 2018-01-01 00:03:00  13550.34
# 2018-01-01 00:04:00  13583.44

# %% [markdown]
# ### Step 2: Get summary statistics and plot the data.
#
# Sort through the time series data associated with the bitstamp and coinbase DataFrames to identify potential arbitrage opportunities. To do so, complete the following steps:
#
# 1. Generate the summary statistics for each DataFrame by using the `describe` function.
#
# 2. For each DataFrame, create a line plot for the full period of time in the dataset. Be sure to tailor the figure size, title, and color to each visualization.
#
# 3. In one plot, overlay the visualizations that you created in Step 2 for bitstamp and coinbase. Be sure to adjust the legend and title for this new visualization.
#
# 4. Using the `loc` and `plot` functions, plot the price action of the assets on each exchange for different dates and times. Your goal is to evaluate how the spread between the two exchanges changed across the time period that the datasets define. Did the degree of spread change as time progressed?

# %%
# Generate the summary statistics for the bitstamp DataFrame
display(bitstamp_sliced.describe())
# Out:
#                Close
# count  129067.000000
# mean    10459.842453
# std      2315.976088
# min      5944.000000
# 25%      8613.370000
# 50%     10145.950000
# 75%     11444.810000
# max     17234.980000

# %%
# Generate the summary statistics for the coinbase DataFrame
display(coinbase_sliced.describe())
# Out:
#                Close
# count  129322.000000
# mean    10449.140958
# std      2317.197419
# min      5882.310000
# 25%      8609.230000
# 50%     10137.440000
# 75%     11397.237500
# max     17177.990000

# %%
# Create a line plot for the bitstamp DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization

bitstamp_sliced.plot(figsize=(15,10), 
                     title="Bitcoin prices on Bitstamp: 1/1/18 to 3/31/18", 
                     color="gold")
# Out:
# <AxesSubplot:title={'center':'Bitcoin prices on Bitstamp: 1/1/18 to 3/31/18'}, xlabel='Timestamp'>

# %%
# Create a line plot for the coinbase DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
coinbase_sliced.plot(figsize=(15,10), 
                     title="Bitcoin prices on Coinbase: 1/1/18 to 3/31/18", 
                     color="purple")
# Out:
# <AxesSubplot:title={'center':'Bitcoin prices on Coinbase: 1/1/18 to 3/31/18'}, xlabel='Timestamp'>

# %%
# Overlay the visualizations for the bitstamp and coinbase DataFrames in one plot
# The plot should visualize the prices over the full lenth of the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
bitstamp['Close'].plot(legend=True, 
                       figsize=(15,10), 
                       title="Bitcoin prices on Bitstamp vs Coinbase: 1/1/18 to 3/31/18",
                       color="gold", label="bitstamp")

coinbase['Close'].plot(legend=True, 
                       figsize=(15,10), 
                       color="purple", 
                       label="coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitcoin prices on Bitstamp vs Coinbase: 1/1/18 to 3/31/18'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period early in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label

bitstamp.loc["2018-01-01":"2018-01-31",'Close'].plot(legend=True, 
                                                     figsize=(15,10), 
                                                     title="Bitstamp and Coinbase Prices: Jan 1st to Jan 31st 2018",
                                                     color="gold", 
                                                     label="bitstamp")

coinbase.loc["2018-01-01":"2018-01-31",'Close'].plot(legend=True, 
                                                     figsize=(15,10), 
                                                     color="purple", 
                                                     label="coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp and Coinbase Prices: Jan 1st to Jan 31st 2018'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period later in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label

bitstamp.loc["2018-02-01":"2018-02-28",'Close'].plot(legend=True, 
                                                     figsize=(15,10), 
                                                     title="Bitcoin prices on Bitstamp and Coinbase (Feb 1st to Feb 28th 2018)",
                                                     color="gold", 
                                                     label="bitstamp")

coinbase.loc["2018-02-01":"2018-02-28",'Close'].plot(legend=True,
                                                     figsize=(15,10), 
                                                     color="purple", 
                                                     label="coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitcoin prices on Bitstamp and Coinbase (Feb 1st to Feb 28th 2018)'}, xlabel='Timestamp'>

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread change as time progressed?
#
# **Answer**
# Overall, the visualizations suggest very close or even trading between Bitstamp and Coinbase for the date ranges of January 1st 2018 to March 31st of 2018. However there are a few days approaching the end of January where there is some degree of spread observed. We will focus on January 29th for subsequent analysis.
# During February there are some small periods of time when spread is observed, but it is shortlived and it does not appear to be of significance to warrant trading risks.

# %% [markdown]
# ### Step 3: Focus Your Analysis on Specific Dates
#
# Focus your analysis on specific dates by completing the following steps:
#
# 1. Select three dates to evaluate for arbitrage profitability. Choose one date that’s early in the dataset, one from the middle of the dataset, and one from the later part of the time period.
#
# 2. For each of the three dates, generate the summary statistics and then create a box plot. This big-picture view is meant to help you gain a better understanding of the data before you perform your arbitrage calculations. As you compare the data, what conclusions can you draw?

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day early in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label`

bitstamp.loc["2018-01-29":"2018-01-29",'Close'].plot(legend=True, 
                                                     figsize=(15,10), 
                                                     title="Bitstamp and Coinbase Price: January 29th",
                                                     color="gold", 
                                                     label="bitstamp")

coinbase.loc["2018-01-29":"2018-01-29",'Close'].plot(legend=True, 
                                                     figsize=(15,10), 
                                                     color="purple",
                                                     label="coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp and Coinbase Price: January 29th'}, xlabel='Timestamp'>

# %%
# Using the early date that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices

arbitrage_spread_early = bitstamp.loc["2018-01-29":"2018-01-29", 'Close'] - coinbase.loc["2018-01-29":"2018-01-29", 'Close']

# Generate summary statistics for the early DataFrame
display(arbitrage_spread_early.describe())
arbitrage_spread_early.head()
# Out:
# count    1430.000000
# mean      120.214510
# std        85.164846
# min       -48.010000
# 25%        37.002500
# 50%       132.420000
# 75%       203.237500
# max       300.270000
# Name: Close, dtype: float64
# Timestamp
# 2018-01-29 00:00:00    201.98
# 2018-01-29 00:01:00    217.00
# 2018-01-29 00:02:00    217.22
# 2018-01-29 00:03:00    223.22
# 2018-01-29 00:04:00    208.64
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from early in the dataset in a box plot
arbitrage_spread_early.plot(figsize=(5,10), 
                            kind="box",
                            title="Arbitrage spread - EARLY DATE",
                            color= 
                            {
                            "boxes": "DarkGreen",
                            "whiskers": "DarkOrange",
                            "medians": "DarkBlue",
                            "caps": "black" })
plt.show()

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from the middle of the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
bitstamp.loc["2018-02-23":"2018-02-23",'Close'].plot(legend=True, 
                                                     figsize=(15,10), 
                                                     title="Bitcoin price on Bitstamp and Coinbase: February 23rd 2018",
                                                     color="green", 
                                                     label="bitstamp")

coinbase.loc["2018-02-23":"2018-02-23",'Close'].plot(legend=True, 
                                                     figsize=(15,10), 
                                                     color="purple",
                                                     label="coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitcoin price on Bitstamp and Coinbase: February 23rd 2018'}, xlabel='Timestamp'>

# %%
# Using the date in the middle that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_middle = bitstamp.loc["2018-02-23":"2018-02-23", 'Close']-coinbase.loc["2018-02-23":"2018-02-23", 'Close']

# Generate summary statistics
display(arbitrage_spread_middle.describe())
arbitrage_spread_middle.head()
# Out:
# count    1437.000000
# mean       13.835741
# std        12.897678
# min       -25.000000
# 25%         5.020000
# 50%        13.740000
# 75%        22.650000
# max        59.010000
# Name: Close, dtype: float64
# Timestamp
# 2018-02-23 00:00:00    40.82
# 2018-02-23 00:01:00    31.08
# 2018-02-23 00:02:00    28.43
# 2018-02-23 00:03:00    36.12
# 2018-02-23 00:04:00    22.95
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from the middle of the dataset in a box plot
arbitrage_spread_middle.plot(figsize=(5,10), 
                             kind="box",
                             color = {    
                                 "boxes": "DarkGreen",
                                 "whiskers": "DarkOrange",
                                 "medians": "DarkBlue",
                                 "caps": "Gray"})
plt.show()

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from late in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
bitstamp.loc["2018-03-23":"2018-03-23",'Close'].plot(legend=True, 
                                                     figsize=(15,10), 
                                                     title="Bitcoin price on Bitstamp and Coinbase: March 23rd 2018",
                                                     color="green", 
                                                     label="bitstamp")

coinbase.loc["2018-03-23":"2018-03-23",'Close'].plot(legend=True, 
                                                     figsize=(15,10), 
                                                     color="purple",
                                                     label="coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitcoin price on Bitstamp and Coinbase: March 23rd 2018'}, xlabel='Timestamp'>

# %%
# Using the date from the late that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_late = bitstamp.loc["2018-03-23":"2018-03-23", 'Close']-coinbase.loc["2018-03-23":"2018-03-23", 'Close']

# Generate summary statistics for the late DataFrame
display(arbitrage_spread_late.describe())
arbitrage_spread_late.tail()
# Out:
# count    1434.000000
# mean        4.552434
# std         8.191096
# min       -32.000000
# 25%        -0.652500
# 50%         4.300000
# 75%        10.000000
# max        38.230000
# Name: Close, dtype: float64
# Timestamp
# 2018-03-23 23:55:00    2.78
# 2018-03-23 23:56:00    2.78
# 2018-03-23 23:57:00    9.44
# 2018-03-23 23:58:00    2.70
# 2018-03-23 23:59:00    3.76
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from late in the dataset in a box plot
arbitrage_spread_late.plot(figsize=(5,10), 
                           kind="box",
                           color = {
                               "boxes": "DarkGreen",
                               "whiskers": "DarkOrange",
                               "medians": "DarkBlue",
                               "caps": "Gray"})
plt.show()

# %% [markdown]
# ### Step 4: Calculate the Arbitrage Profits
#
# Calculate the potential profits for each date that you selected in the previous section. Your goal is to determine whether arbitrage opportunities still exist in the Bitcoin market. Complete the following steps:
#
# 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.
#
# 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.
#
# 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?
#
# 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.
#
# 6. Generate the summary statistics, and plot the results for each of the three DataFrames.
#
# 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.
#
# 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?
#
# (NOTE: The starter code displays only one date. You'll want to do this analysis for two additional dates).

# %% [markdown]
# #### 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# *NOTE*: For illustration, only one of the three dates is shown in the starter code below.

# %%
# For the date early in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
# EARLY DATE: January 29th 2018
print("Arbitrage Spread - Early Date: January 29th 2018")
arbitrage_spread_early = bitstamp.loc["2018-01-29":"2018-01-29", "Close"]-coinbase.loc["2018-01-29":"2018-01-29", "Close"]
print(arbitrage_spread_early)


# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
#Early Date: January 29th 2018
print()
print("Early Date Statistics: January 29th 2018")
early_boolean_filter = arbitrage_spread_early > 0
arbitrage_spread_early.loc[early_boolean_filter].describe()
# Out:
# Arbitrage Spread - Early Date: January 29th 2018
# Timestamp
# 2018-01-29 00:00:00    201.98
# 2018-01-29 00:01:00    217.00
# 2018-01-29 00:02:00    217.22
# 2018-01-29 00:03:00    223.22
# 2018-01-29 00:04:00    208.64
#                         ...
# 2018-01-29 23:55:00     23.62
# 2018-01-29 23:56:00     -7.29
# 2018-01-29 23:57:00     18.31
# 2018-01-29 23:58:00      2.39
# 2018-01-29 23:59:00      5.92
# Name: Close, Length: 1440, dtype: float64
#
# Early Date Statistics: January 29th 2018
# count    1379.000000
# mean      124.976425
# std        82.959829
# min         0.570000
# 25%        41.885000
# 50%       144.380000
# 75%       204.135000
# max       300.270000
# Name: Close, dtype: float64

# %%
#MIDDLE DATE: February 23th 2018
print("Arbitrage Spread - Middle Date: February 23rd 2018")
arbitrage_spread_middle = bitstamp.loc["2018-02-23":"2018-02-23","Close"]-coinbase.loc["2018-02-23":"2018-02-23","Close"]
print(arbitrage_spread_middle)

print()
print("Middle Date Statistics: February 23th 2018")
middle_boolean_filter = arbitrage_spread_middle > 0
arbitrage_spread_middle.loc[middle_boolean_filter].describe()
# Out:
# Arbitrage Spread - Middle Date: February 23rd 2018
# Timestamp
# 2018-02-23 00:00:00    40.82
# 2018-02-23 00:01:00    31.08
# 2018-02-23 00:02:00    28.43
# 2018-02-23 00:03:00    36.12
# 2018-02-23 00:04:00    22.95
#                        ...
# 2018-02-23 23:55:00   -17.16
# 2018-02-23 23:56:00     7.95
# 2018-02-23 23:57:00     9.05
# 2018-02-23 23:58:00    15.74
# 2018-02-23 23:59:00    20.40
# Name: Close, Length: 1440, dtype: float64
#
# Middle Date Statistics: February 23th 2018
# count    1247.000000
# mean       16.993601
# std        10.536648
# min         0.040000
# 25%         8.660000
# 50%        15.920000
# 75%        24.010000
# max        59.010000
# Name: Close, dtype: float64

# %%
#LATER DATE: March 23rd 2018
print("Arbitrage Spread - Later Date: Marh 23rd 2018")
arbitrage_spread_late = bitstamp.loc["2018-03-23":"2018-03-23","Close"]-coinbase.loc["2018-03-23":"2018-03-23","Close"]
print(arbitrage_spread_late)

print()
print("Later Date Statistics: March 23rd 2018")
late_boolean_filter = arbitrage_spread_late > 0
arbitrage_spread_late.loc[late_boolean_filter].describe()
# Out:
# Arbitrage Spread - Later Date: Marh 23rd 2018
# Timestamp
# 2018-03-23 00:00:00     5.49
# 2018-03-23 00:01:00     1.44
# 2018-03-23 00:02:00     3.52
# 2018-03-23 00:03:00    11.15
# 2018-03-23 00:04:00    11.97
#                        ...
# 2018-03-23 23:55:00     2.78
# 2018-03-23 23:56:00     2.78
# 2018-03-23 23:57:00     9.44
# 2018-03-23 23:58:00     2.70
# 2018-03-23 23:59:00     3.76
# Name: Close, Length: 1440, dtype: float64
#
# Later Date Statistics: March 23rd 2018
# count    1022.000000
# mean        8.325440
# std         6.041374
# min         0.010000
# 25%         3.645000
# 50%         6.990000
# 75%        12.010000
# max        38.230000
# Name: Close, dtype: float64

# %% [markdown]
# #### 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
spread_return_early= arbitrage_spread_early[arbitrage_spread_early > 0] / coinbase_sliced["Close"].loc["2018-01-29"]

# Review the spread return DataFrame
print()
print("Spread return for EARLY DATE of January 29th 2018")
spread_return_early
# Out:
# Spread return for EARLY DATE of January 29th 2022
# Timestamp
# 2018-01-29 00:00:00    0.017925
# 2018-01-29 00:01:00    0.019284
# 2018-01-29 00:02:00    0.019307
# 2018-01-29 00:03:00    0.019840
# 2018-01-29 00:04:00    0.018541
#                          ...
# 2018-01-29 23:55:00    0.002155
# 2018-01-29 23:56:00         NaN
# 2018-01-29 23:57:00    0.001672
# 2018-01-29 23:58:00    0.000218
# 2018-01-29 23:59:00    0.000541
# Name: Close, Length: 1440, dtype: float64

# %%
#Middle Date: February 23rd 2018
spread_return_middle = arbitrage_spread_middle[arbitrage_spread_middle > 0] / coinbase_sliced["Close"].loc["2018-02-23"]

# Review the spread return DataFrame
print()
print("Spread return for MIDDLE DATE of February 23rd 2018")
spread_return_middle
# Out:
# Spread return for MIDDLE DATE of February 23rd 2018
# Timestamp
# 2018-02-23 00:00:00    0.004154
# 2018-02-23 00:01:00    0.003159
# 2018-02-23 00:02:00    0.002890
# 2018-02-23 00:03:00    0.003668
# 2018-02-23 00:04:00    0.002330
#                          ...
# 2018-02-23 23:55:00         NaN
# 2018-02-23 23:56:00    0.000765
# 2018-02-23 23:57:00    0.000871
# 2018-02-23 23:58:00    0.001514
# 2018-02-23 23:59:00    0.001963
# Name: Close, Length: 1440, dtype: float64

# %%
#trying to understand the NaN value on the for Timestamp of 2018-02-23 23:55:00
#it actually is a Negative number, thus it is not included in the calculation for Arbitrage Spread.
#Understanding the NUMERATOR
#this is OK!
arbitrage_spread_middle.loc["2018-02-23 23:55:00"]
# Out:
# -17.159999999999854

# %%
#I want to look at the price on COINBASE for Feb 23rd
#understanding the DENOMINATOR
arbitrage_spread_middle[arbitrage_spread_middle > 0]
# Out:
# Timestamp
# 2018-02-23 00:00:00    40.82
# 2018-02-23 00:01:00    31.08
# 2018-02-23 00:02:00    28.43
# 2018-02-23 00:03:00    36.12
# 2018-02-23 00:04:00    22.95
#                        ...
# 2018-02-23 23:54:00     2.23
# 2018-02-23 23:56:00     7.95
# 2018-02-23 23:57:00     9.05
# 2018-02-23 23:58:00    15.74
# 2018-02-23 23:59:00    20.40
# Name: Close, Length: 1247, dtype: float64

# %%
#Removing NaN from the Spread Return Middle
#Observation: There are NO values > 0.01
spread_return_middle = spread_return_middle.dropna()
spread_return_middle
# Out:
# Timestamp
# 2018-03-23 00:00:00    0.000653
# 2018-03-23 00:01:00    0.000171
# 2018-03-23 00:02:00    0.000419
# 2018-03-23 00:03:00    0.001327
# 2018-03-23 00:04:00    0.001425
#                          ...
# 2018-03-23 23:55:00    0.000313
# 2018-03-23 23:56:00    0.000313
# 2018-03-23 23:57:00    0.001064
# 2018-03-23 23:58:00    0.000304
# 2018-03-23 23:59:00    0.000424
# Name: Close, Length: 1022, dtype: float64

# %%
#Spread returns for LATER DATE
#Later Date: March 23rd 2018
spread_return_late = arbitrage_spread_late[arbitrage_spread_late > 0] / coinbase_sliced["Close"].loc["2018-03-23"]

# Review the spread return DataFrame
print()
print("Spread Return LATE DATE March 23rd 2018")
spread_return_late
# Out:
# Spread Return LATE DATE March 23rd 2018
# Timestamp
# 2018-03-23 00:00:00    0.000653
# 2018-03-23 00:01:00    0.000171
# 2018-03-23 00:02:00    0.000419
# 2018-03-23 00:03:00    0.001327
# 2018-03-23 00:04:00    0.001425
#                          ...
# 2018-03-23 23:55:00    0.000313
# 2018-03-23 23:56:00    0.000313
# 2018-03-23 23:57:00    0.001064
# 2018-03-23 23:58:00    0.000304
# 2018-03-23 23:59:00    0.000424
# Name: Close, Length: 1440, dtype: float64

# %% [markdown]
# #### 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.

# %%
# For the date early in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
#EARLY DATE
profitable_trades_early = spread_return_early > .01

# Review the first five profitable trades
print()
print("Profitable trades EARLY DATE")
profitable_trades_early = spread_return_early.loc[profitable_trades_early]
profitable_trades_early.head()
# Out:
# Profitable trades EARLY DATE
#
# Profitable trades EARLY DATE:  742

# %%
#MIDDLE DATE
profitable_trades_middle = spread_return_middle > .01

# Review the first five profitable trades
print()
print("Profitable trades MIDDLE DATE")
profitable_trades_middle = spread_return_middle.loc[profitable_trades_middle]
profitable_trades_middle.head()
# Out:
# Profitable trades MIDDLE DATE
# Series([], Name: Close, dtype: float64)

# %%
#LATER DATE
profitable_trades_late = spread_return_late > .01

# Review the first five profitable trades
print()
print("Profitable trades LATER DATE")
profitable_trades_late = spread_return_late.loc[profitable_trades_late]
profitable_trades_late.head()
# Out:
# Profitable trades LATER DATE
# Series([], Name: Close, dtype: float64)

# %%
print("Analysis of Profitable Trades EARLY, MIDDLE, LATE")
print()
print("Profitable trades EARLY DATE: ", len(profitable_trades_early))
print("Profitable trades MIDDLE DATE: ", len(profitable_trades_middle))
print("Profitable trades LATER DATE: ", len(profitable_trades_late))
# Out:
# Analysis of Profitable Trades EARLY, MIDDLE, LATE
#
# Profitable trades EARLY DATE:  742
# Profitable trades MIDDLE DATE:  0
# Profitable trades LATER DATE:  0

# %% [markdown]
# #### 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?

# %%
# For the date early in the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%

display(profitable_trades_early.describe())
display(profitable_trades_middle.describe())
profitable_trades_late.describe()
# Out:
# count    742.000000
# mean       0.017795
# std        0.003142
# min        0.010021
# 25%        0.015371
# 50%        0.018233
# 75%        0.020063
# max        0.027075
# Name: Close, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %%
print("Question: How do the average returns compare among the 3 dates?")
# Out:
# Question: How do the average returns compare among the 3 dates?

# %%
print("Answer:")
print("The only date that demonstrates any returns is the EARLY date of January 29th, the other dates do not provide any returns greater than 1%")
# Out:
# Answer:
# The only date that demonstrates any returns is the EARLY date of January 29th, the other dates do not provide any returns greater than 1%

# %% [markdown]
# #### 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased

profit_per_trade_early = profitable_trades_early * coinbase_sliced["Close"].loc["2018-01-29"]
profit_per_trade_middle = profitable_trades_middle * bitstamp_sliced["Close"].loc["2018-02-23"]
profit_per_trade_late = profitable_trades_late * coinbase_sliced["Close"].loc["2018-03-23"]

# Drop any missing values from the profit DataFrame

profit_per_trade_early = profit_per_trade_early.dropna()
profit_per_trade_middle = profit_per_trade_middle.dropna()
profit_per_trade_late = profit_per_trade_late.dropna()

# View the early profit DataFrame
print("Profits per trade Early")
display(profit_per_trade_early,len(profit_per_trade_early))
print()
print("Profits per trade Middle")
display(profit_per_trade_middle,len(profit_per_trade_middle))
print()
print("Profits per trade Late")
display(profit_per_trade_late,len(profit_per_trade_late))
print()
# Out:
# Profits per trade Early
# Timestamp
# 2018-01-29 00:00:00    201.98
# 2018-01-29 00:01:00    217.00
# 2018-01-29 00:02:00    217.22
# 2018-01-29 00:03:00    223.22
# 2018-01-29 00:04:00    208.64
#                         ...
# 2018-01-29 12:24:00    116.54
# 2018-01-29 12:31:00    128.44
# 2018-01-29 12:33:00    121.93
# 2018-01-29 12:37:00    111.42
# 2018-01-29 12:39:00    112.75
# Name: Close, Length: 742, dtype: float64
# 742
# Profits per trade Middle
# Series([], Name: Close, dtype: float64)
# 0
# Profits per trade Late
# Series([], Name: Close, dtype: float64)
# 0

# %% [markdown]
# #### 6. Generate the summary statistics, and plot the results for each of the three DataFrames.

# %%
# Generate the summary statistics for the early profit per trade DataFrame
print("Profits per trade Early Statistical Analysis")
display(profit_per_trade_early.describe())
print()
print("Profits per trade Middle Statistical Analysis")
display(profit_per_trade_middle.describe())
print()
print("Profits per trade Later Statistical Analysis")
profit_per_trade_late.describe()
# Out:
# Profits per trade Early Statistical Analysis
# count    742.000000
# mean     196.724070
# std       34.604234
# min      111.200000
# 25%      170.037500
# 50%      200.930000
# 75%      221.002500
# max      300.270000
# Name: Close, dtype: float64
# Profits per trade Middle Statistical Analysis
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64
# Profits per trade Later Statistical Analysis
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %%
# Plot the results for the early profit per trade DataFrame
profit_per_trade_early.plot(legend=True,
                            xlabel="Time",
                            ylabel="Profit",
                            figsize=(10,7),
                            title="Profit per Trade EARLY Date",
                            color="green",
                            label="Close price $")
# Out:
# <AxesSubplot:title={'center':'Profit per Trade EARLY Date'}, xlabel='Time', ylabel='Profit'>

# %%
profit_per_trade_middle.plot(legend=True,
                            xlabel="Time",
                            ylabel="Profit",
                            figsize=(10,7),
                            title="Profit per Trade Middle Date",
                            color="green",
                            label="Close price $")
# Out:
# <AxesSubplot:title={'center':'Profit per Trade Middle Date'}, xlabel='Time', ylabel='Profit'>

# %%
profit_per_trade_late.plot(legend=True,
                            xlabel="Time",
                            ylabel="Profit",
                            figsize=(10,7),
                            title="Profit per Trade LATER Date",
                            color="green",
                            label="Close price $")
# Out:
# <AxesSubplot:title={'center':'Profit per Trade LATER Date'}, xlabel='Time', ylabel='Profit'>

# %% [markdown]
# #### 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.

# %%
# Calculate the sum of the potential profits for the early profit per trade DataFrame
print("Potential arbitrate profits tha could be made each day: EARLY Date")
display(profit_per_trade_early.sum())
print()
print("Potential arbitrate profits tha could be made each day: MIDDLE Date")
display(profit_per_trade_middle.sum())
print()
print("Potential arbitrate profits tha could be made each day: LATE Date")
display(profit_per_trade_late.sum())
print()
# Out:
# Potential arbitrate profits tha could be made each day: EARLY Date
# 145969.25999999995
# Potential arbitrate profits tha could be made each day: MIDDLE Date
# 0.0
# Potential arbitrate profits tha could be made each day: LATE Date
# 0.0

# %% [markdown]
# #### 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?

# %%
# Use the cumsum function to calculate the cumulative profits over time for the early profit per trade DataFrame
cumulative_profit_early = profit_per_trade_early.cumsum()

# %%
# Plot the cumulative sum of profits for the early profit per trade DataFrame
cumulative_profit_early.plot(legend=True,
                            xlabel="Time",
                            ylabel="Profit",
                            figsize=(10,7),
                            title="Cumulative profit EARLY Date: Jan 29th 2018",
                            color="green",
                            label="Close price $")
# Out:
# <AxesSubplot:title={'center':'Cumulative profit EARLY Date: Jan 29th 2018'}, xlabel='Time', ylabel='Profit'>

# %%
cumulative_profit_middle = profit_per_trade_middle.cumsum()

# %%
cumulative_profit_middle.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
cumulative_profit_late = profit_per_trade_late.cumsum()

# %%
cumulative_profit_late.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:**
# Through this analysis we have 3 different dates that were selected to assess for arbitrage profits between Bitstamp and Coinbase. The selected dates were:  01/29/2018, 02/23/2018, and 03/23/2018. For this analysis, were refer to each date as EARLY, MIDDLE, and LATER.
# Looking at the Bitcoin process on Bitstamp, and Coinbase throughout entire dataset as plotted historically we can observe that there the was a greater spread around the end of January.  January 29th, 2018 was selected for futher analysis.  Profit possibilities were found on 1/29/18.  Where the average price of Bitcoin could have provided a profit averaging $196 per trade.
# The Middle and Later dates did not provide any profit opportunities, this is noted when calculating the spread between Bitstamp and Coinbase for these dates, indicating that there was not a difference in their close price.
# We can conclude that the Bitcoin dropped between January and the end of March, with more opportunities for arbitrage profits during the end of January. Bitcoin prices continued to decline and increase over the course of time, with an overall downward trend as March 2018 ended.
